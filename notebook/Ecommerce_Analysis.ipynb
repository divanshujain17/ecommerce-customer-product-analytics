# %%
import pandas as pd

customers = pd.read_csv('C:/Users/14SFQ1092AU/Documents/Career/Projects/Project/E-commerce_analytics-segmentation_cohort_performance/datasets/olist_customers_dataset.csv')
orders = pd.read_csv('C:/Users/14SFQ1092AU/Documents/Career/Projects/Project/E-commerce_analytics-segmentation_cohort_performance/datasets/olist_orders_dataset.csv')
items = pd.read_csv('C:/Users/14SFQ1092AU/Documents/Career/Projects/Project/E-commerce_analytics-segmentation_cohort_performance/datasets/olist_order_items_dataset.csv')
payments = pd.read_csv('C:/Users/14SFQ1092AU/Documents/Career/Projects/Project/E-commerce_analytics-segmentation_cohort_performance/datasets/olist_order_payments_dataset.csv')
products = pd.read_csv('C:/Users/14SFQ1092AU/Documents/Career/Projects/Project/E-commerce_analytics-segmentation_cohort_performance/datasets/olist_products_dataset.csv')

# %%
customers.shape
# Out:
# (99441, 5)

# %%
orders.shape
# Out:
# (99441, 8)

# %%
items.shape
# Out:
# (112650, 7)

# %%
payments.shape
# Out:
# (103886, 5)

# %%
products.shape
# Out:
# (32951, 9)

# %%
customers.columns
# Out:
# Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
items.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='object')

# %%
payments.columns
# Out:
# Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='object')

# %%
products.columns
# Out:
# Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='object')
